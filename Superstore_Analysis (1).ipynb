# %% [markdown]
# ## Download the dataset from this [link](https://docs.google.com/spreadsheets/d/1GPDvt-JML8G5zFClVCtzaiu6hOEBzjcMHOrNnpK1NjA/edit?usp=sharing). You can find the dataset description there itself. Read it carefully and answer the questions below
#
# **Make sure you write necessary Python code and use necessary visuals to support your answer**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\lenovo\Downloads\Sample Superstore - Sheet1.csv")

# %%
df
# Out:
#           Ship   Mode    Segment Country    City        State      Postal  \
# 0       Second  Class   Consumer  United  States    Henderson    Kentucky
# 1       Second  Class   Consumer  United  States    Henderson    Kentucky
# 2       Second  Class  Corporate  United  States          Los     Angeles
# 3     Standard  Class   Consumer  United  States         Fort  Lauderdale
# 4     Standard  Class   Consumer  United  States         Fort  Lauderdale
# ...        ...    ...        ...     ...     ...          ...         ...
# 9989    Second  Class   Consumer  United  States        Miami     Florida
# 9990  Standard  Class   Consumer  United  States        Costa        Mesa
# 9991  Standard  Class   Consumer  United  States        Costa        Mesa
# 9992  Standard  Class   Consumer  United  States        Costa        Mesa
# 9993    Second  Class   Consumer  United  States  Westminster  California
#
#             Code Region   Category Sub-Category        Sales  Quantity  \
# ...

# %% [markdown]
# #### Find out the dataset dimensions

# %%
df.shape
# Out:
# (9994, 17)

# %%
df.isnull().sum()
# Out:
# Ship               0
# Mode               0
# Segment            0
# Country            0
# City               0
# State              0
# Postal             0
# Code               0
# Region             0
# Category           0
# Sub-Category       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# Unnamed: 15     9365
# Unnamed: 16     9903
# dtype: int64

# %%
df.drop(columns="Unnamed: 15",inplace=True)
df.drop(columns="Unnamed: 16",inplace=True)

# %%
for i in df.columns:
    unique_values = df[i].unique()
    print(f"{i}:\n {unique_values}\n")
# Out:
# Ship:
#  ['Second' 'Standard' 'First' 'Same']
#
# Mode:
#  ['Class' 'Day']
#
# Segment:
#  ['Consumer' 'Corporate' 'Home']
#
# Country:
#  ['United' 'Office']
#
# City:
#  ['States' 'United']
#
# State:
#  ['Henderson' 'Los' 'Fort' 'Concord' 'Seattle' 'States' 'Madison' 'West'
#  'San' 'Fremont' 'Philadelphia' 'Orem' 'Richardson' 'Naperville'
#  'Melbourne' 'Eagan' 'Westland' 'Dover' 'New' 'Troy' 'Gilbert'
#  'Springfield' 'Jackson' 'Memphis' 'Houston' 'Decatur' 'Durham' 'Columbia'
#  'Rochester' 'Minneapolis' 'Saint' 'Aurora' 'Charlotte' 'Urbandale'
#  'Columbus' 'Bristol' 'Wilmington' 'Bloomington' 'Phoenix' 'Roseville'
#  'Independence' 'Pasadena' 'Franklin' 'Edmond' 'Carlsbad' 'Chicago'
#  'Newark' 'Fairfield' 'Grand' 'Redlands' 'Hamilton' 'Akron' 'Denver'
#  'Dallas' 'Whittier' 'Saginaw' 'Medina' 'Dublin' 'Detroit' 'Santa'
#  'Brentwood' 'Chapel' 'Morristown' 'Cincinnati' 'Inglewood' 'Portland'
#  'Tamarac' 'Colorado' 'Belleville' 'Taylor' 'Arlington' 'Arvada'
# ...

# %%
df.isnull().sum()
# Out:
# Ship            0
# Mode            0
# Segment         0
# Country         0
# City            0
# State           0
# Postal          0
# Code            0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.dtypes
# Out:
# Ship            object
# Mode            object
# Segment         object
# Country         object
# City            object
# State           object
# Postal          object
# Code            object
# Region          object
# Category        object
# Sub-Category    object
# Sales           object
# Quantity        object
# Discount        object
# Profit          object
# dtype: object

# %%
for i in df.columns:
    unique_values = df[i].unique()
    print(f"{i}:\n {unique_values}\n")
# Out:
# Ship:
#  ['Second' 'Standard' 'First' 'Same']
#
# Mode:
#  ['Class' 'Day']
#
# Segment:
#  ['Consumer' 'Corporate' 'Home']
#
# Country:
#  ['United' 'Office']
#
# City:
#  ['States' 'United']
#
# State:
#  ['Henderson' 'Los' 'Fort' 'Concord' 'Seattle' 'States' 'Madison' 'West'
#  'San' 'Fremont' 'Philadelphia' 'Orem' 'Richardson' 'Naperville'
#  'Melbourne' 'Eagan' 'Westland' 'Dover' 'New' 'Troy' 'Gilbert'
#  'Springfield' 'Jackson' 'Memphis' 'Houston' 'Decatur' 'Durham' 'Columbia'
#  'Rochester' 'Minneapolis' 'Saint' 'Aurora' 'Charlotte' 'Urbandale'
#  'Columbus' 'Bristol' 'Wilmington' 'Bloomington' 'Phoenix' 'Roseville'
#  'Independence' 'Pasadena' 'Franklin' 'Edmond' 'Carlsbad' 'Chicago'
#  'Newark' 'Fairfield' 'Grand' 'Redlands' 'Hamilton' 'Akron' 'Denver'
#  'Dallas' 'Whittier' 'Saginaw' 'Medina' 'Dublin' 'Detroit' 'Santa'
#  'Brentwood' 'Chapel' 'Morristown' 'Cincinnati' 'Inglewood' 'Portland'
#  'Tamarac' 'Colorado' 'Belleville' 'Taylor' 'Arlington' 'Arvada'
# ...

# %%
df['Region'] = df['Region'].str.replace('\d+', '')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4700\926086216.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Region'] = df['Region'].str.replace('\d+', '')

# %%
df["Code"]=df["Code"].replace('\D','',regex=True)

# %%
df.drop(df[df["Region"].isin(['', 'Texas', 'New', 'City',
       'Illinois', 'California', 'Jersey', 'Carolina', 'Nevada',
       'Montana', 'York', 'Hampshire', 'Columbia', 'Missouri', 'of',
       'Florida', 'Island', 'Dakota', 'Colorado', 'Oklahoma', 'Mexico',
       'Michigan', 'Wisconsin', 'Virginia', 'Washington', 'Minnesota',
       'Utah', 'Iowa', 'Louisiana', 'Arkansas', 'Vegas', 'Beach',
       'Georgia'])].index, inplace=True)

# %%
for i in df.columns:
    unique_values = df[i].unique()
    print(f"{i}:\n {unique_values}\n")
# Out:
# Ship:
#  ['Second' 'Standard' 'First' 'Same']
#
# Mode:
#  ['Class' 'Day']
#
# Segment:
#  ['Consumer' 'Corporate']
#
# Country:
#  ['United']
#
# City:
#  ['States']
#
# State:
#  ['Henderson' 'Seattle' 'Madison' 'Fremont' 'Philadelphia' 'Orem'
#  'Richardson' 'Naperville' 'Melbourne' 'Eagan' 'Westland' 'Dover'
#  'Gilbert' 'Springfield' 'Jackson' 'Memphis' 'Houston' 'Decatur'
#  'Rochester' 'Minneapolis' 'Aurora' 'Urbandale' 'Columbus' 'Bristol'
#  'Wilmington' 'Bloomington' 'Phoenix' 'Roseville' 'Independence'
#  'Pasadena' 'Franklin' 'Edmond' 'Chicago' 'Newark' 'Fairfield' 'Redlands'
#  'Hamilton' 'Akron' 'Denver' 'Dallas' 'Whittier' 'Saginaw' 'Medina'
#  'Dublin' 'Detroit' 'Columbia' 'Brentwood' 'Cincinnati' 'Inglewood'
#  'Portland' 'Tamarac' 'Taylor' 'Arlington' 'Arvada' 'Hesperia'
#  'Murfreesboro' 'Layton' 'Austin' 'Lowell' 'Manchester' 'Harlingen'
#  'Tucson' 'Quincy' 'Peoria' 'Miami' 'Richmond' 'Louisville' 'Lawrence'
# ...

# %%
df.drop(df[(df['Sales'] == 'Binders')].index,inplace=True)

# %%
df
# Out:
#           Ship   Mode    Segment Country    City        State      Postal  \
# 0       Second  Class   Consumer  United  States    Henderson    Kentucky
# 1       Second  Class   Consumer  United  States    Henderson    Kentucky
# 16    Standard  Class   Consumer  United  States      Madison   Wisconsin
# 21    Standard  Class  Corporate  United  States      Fremont    Nebraska
# 22    Standard  Class  Corporate  United  States      Fremont    Nebraska
# ...        ...    ...        ...     ...     ...          ...         ...
# 9981     First  Class   Consumer  United  States    Fairfield        Ohio
# 9987  Standard  Class  Corporate  United  States       Athens     Georgia
# 9988  Standard  Class  Corporate  United  States       Athens     Georgia
# 9989    Second  Class   Consumer  United  States        Miami     Florida
# 9993    Second  Class   Consumer  United  States  Westminster  California
#
#        Code   Region    Category Sub-Category       Sales Quantity Discount  \
# ...

# %%
df.isnull().sum()
# Out:
# Ship            0
# Mode            0
# Segment         0
# Country         0
# City            0
# State           0
# Postal          0
# Code            0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
for i in df.columns:
    unique_values = df[i].unique()
    print(f"{i}:\n {unique_values}\n")
# Out:
# Ship:
#  ['Second' 'Standard' 'First' 'Same']
#
# Mode:
#  ['Class' 'Day']
#
# Segment:
#  ['Consumer' 'Corporate']
#
# Country:
#  ['United']
#
# City:
#  ['States']
#
# State:
#  ['Henderson' 'Madison' 'Fremont' 'Philadelphia' 'Orem' 'Richardson'
#  'Naperville' 'Melbourne' 'Eagan' 'Westland' 'Dover' 'Gilbert'
#  'Springfield' 'Jackson' 'Memphis' 'Houston' 'Decatur' 'Rochester'
#  'Minneapolis' 'Aurora' 'Urbandale' 'Columbus' 'Seattle' 'Wilmington'
#  'Bloomington' 'Phoenix' 'Roseville' 'Independence' 'Pasadena' 'Franklin'
#  'Edmond' 'Chicago' 'Newark' 'Redlands' 'Hamilton' 'Akron' 'Denver'
#  'Dallas' 'Whittier' 'Saginaw' 'Medina' 'Dublin' 'Detroit' 'Columbia'
#  'Brentwood' 'Cincinnati' 'Inglewood' 'Portland' 'Tamarac' 'Taylor'
#  'Arlington' 'Arvada' 'Hesperia' 'Murfreesboro' 'Layton' 'Austin' 'Lowell'
#  'Manchester' 'Harlingen' 'Tucson' 'Quincy' 'Miami' 'Richmond'
#  'Louisville' 'Lawrence' 'Canton' 'Jacksonville' 'Norman' 'Concord'
# ...

# %%
df["Sales"].value_counts()
# Out:
# Paper         631
# Storage       435
# Art           386
# Appliances    239
# Labels        171
#              ...
# 2430.08         1
# 5.352           1
# 87.168          1
# 657.552         1
# 25.248          1
# Name: Sales, Length: 1598, dtype: int64

# %%
df["Sales"]=df["Sales"].replace('\D','',regex=True)

# %%
df
# Out:
#           Ship   Mode    Segment Country    City         State        Postal  \
# 0       Second  Class   Consumer  United  States     Henderson      Kentucky
# 1       Second  Class   Consumer  United  States     Henderson      Kentucky
# 23      Second  Class   Consumer  United  States  Philadelphia  Pennsylvania
# 24    Standard  Class   Consumer  United  States          Orem          Utah
# 27    Standard  Class   Consumer  United  States  Philadelphia  Pennsylvania
# ...        ...    ...        ...     ...     ...           ...           ...
# 9964    Second  Class  Corporate  United  States        Newark      Delaware
# 9980    Second  Class   Consumer  United  States     Lafayette     Louisiana
# 9987  Standard  Class  Corporate  United  States        Athens       Georgia
# 9988  Standard  Class  Corporate  United  States        Athens       Georgia
# 9989    Second  Class   Consumer  United  States         Miami       Florida
#
# ...

# %%
df.drop(df[(df['Sales'] == '')].index,inplace=True)

# %%
df
# Out:
#           Ship   Mode    Segment Country    City         State        Postal  \
# 0       Second  Class   Consumer  United  States     Henderson      Kentucky
# 1       Second  Class   Consumer  United  States     Henderson      Kentucky
# 23      Second  Class   Consumer  United  States  Philadelphia  Pennsylvania
# 24    Standard  Class   Consumer  United  States          Orem          Utah
# 27    Standard  Class   Consumer  United  States  Philadelphia  Pennsylvania
# ...        ...    ...        ...     ...     ...           ...           ...
# 9964    Second  Class  Corporate  United  States        Newark      Delaware
# 9980    Second  Class   Consumer  United  States     Lafayette     Louisiana
# 9987  Standard  Class  Corporate  United  States        Athens       Georgia
# 9988  Standard  Class  Corporate  United  States        Athens       Georgia
# 9989    Second  Class   Consumer  United  States         Miami       Florida
#
# ...

# %%
for i in df.columns:
    unique_values = df[i].unique()
    print(f"{i}:\n {unique_values}\n")
# Out:
# Ship:
#  ['Second' 'Standard' 'First' 'Same']
#
# Mode:
#  ['Class' 'Day']
#
# Segment:
#  ['Consumer' 'Corporate']
#
# Country:
#  ['United']
#
# City:
#  ['States']
#
# State:
#  ['Henderson' 'Philadelphia' 'Orem' 'Richardson' 'Naperville' 'Eagan'
#  'Dover' 'Gilbert' 'Memphis' 'Houston' 'Rochester' 'Minneapolis' 'Aurora'
#  'Seattle' 'Wilmington' 'Bloomington' 'Columbus' 'Roseville' 'Franklin'
#  'Edmond' 'Newark' 'Decatur' 'Denver' 'Whittier' 'Saginaw' 'Dallas'
#  'Medina' 'Dublin' 'Detroit' 'Columbia' 'Chicago' 'Brentwood' 'Portland'
#  'Arvada' 'Hesperia' 'Murfreesboro' 'Manchester' 'Tucson' 'Taylor'
#  'Louisville' 'Lawrence' 'Jackson' 'Canton' 'Jacksonville' 'Akron'
#  'Norman' 'Concord' 'Amarillo' 'Parker' 'Gladstone' 'Montgomery' 'Tampa'
#  'Richmond' 'Salem' 'Laredo' 'Dearborn' 'Miami' 'Vancouver' 'Arlington'
#  'Cleveland' 'Tyler' 'Waynesboro' 'Austin' 'Evanston' 'Trenton'
#  'Lancaster' 'Omaha' 'Edmonds' 'Florence' 'Lorain' 'Springfield'
# ...

# %%
df.dtypes
# Out:
# Ship            object
# Mode            object
# Segment         object
# Country         object
# City            object
# State           object
# Postal          object
# Code            object
# Region          object
# Category        object
# Sub-Category    object
# Sales           object
# Quantity        object
# Discount        object
# Profit          object
# dtype: object

# %%
df.columns
# Out:
# Index(['Ship', 'Mode', 'Segment', 'Country', 'City', 'State', 'Postal', 'Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
col=['Sales', 'Quantity', 'Discount',
       'Profit',"Code"]

# %%
for i in col:
    df[i] = pd.to_numeric(df[i],errors="coerce")

# %%
df.dtypes
# Out:
# Ship             object
# Mode             object
# Segment          object
# Country          object
# City             object
# State            object
# Postal           object
# Code              int64
# Region           object
# Category         object
# Sub-Category     object
# Sales             int64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
col=['Sales', 'Quantity', 'Discount',
       'Profit',"Code"]

# %%
for c in col:  
    percentile25=df[c].quantile(0.25)
    percentile75=df[c].quantile(0.75)
    iqr=percentile75-percentile25
    upper_limit=percentile75+(1.5*iqr)
    lower_limit=percentile25-(1.5*iqr)
    print(c,':',df.shape[0]-(df[(df[c]<=upper_limit) & (df[c]>=lower_limit)].shape[0]))
# Out:
# Sales : 235
# Quantity : 33
# Discount : 0
# Profit : 360
# Code : 0

# %%
for c in col:  
    percentile25=df[c].quantile(0.25)
    percentile75=df[c].quantile(0.75)
    iqr=percentile75-percentile25
    upper_limit=percentile75+(2*iqr)
    lower_limit=percentile25-(2*iqr)
    print(c,':',df.shape[0]-(df[(df[c]<=upper_limit) & (df[c]>=lower_limit)].shape[0]))
# Out:
# Sales : 189
# Quantity : 16
# Discount : 0
# Profit : 287
# Code : 0

# %%
df['Ship_Mode'] = df['Ship'] + ' ' + df['Mode']

# %%
df.drop(columns="Ship",inplace=True)

# %%
df.drop(columns="Mode",inplace=True)

# %%
df.head(5)
# Out:
#      Segment Country    City         State        Postal   Code Region  \
# 0   Consumer  United  States     Henderson      Kentucky  42420  South
# 1   Consumer  United  States     Henderson      Kentucky  42420  South
# 23  Consumer  United  States  Philadelphia  Pennsylvania  19140   East
# 24  Consumer  United  States          Orem          Utah  84057   West
# 27  Consumer  United  States  Philadelphia  Pennsylvania  19140   East
#
#      Category Sub-Category   Sales  Quantity  Discount     Profit  \
# 0   Furniture    Bookcases   26196         2       0.0    41.9136
# 1   Furniture       Chairs   73194         3       0.0   219.5820
# 23  Furniture       Chairs   71372         2       0.3    -1.0196
# 24  Furniture       Tables  104463         3       0.0   240.2649
# 27  Furniture    Bookcases  308343         7       0.5 -1665.0500
#
#          Ship_Mode
# 0     Second Class
# 1     Second Class
# 23    Second Class
# 24  Standard Class
# 27  Standard Class

# %%
sns.set(rc={'figure.figsize':(20,8)})

plt.bar(df['Ship_Mode'],df['Quantity'], color='green')
# Out:
# <BarContainer object of 1917 artists>

# %%
sns.set(rc={'figure.figsize':(20,8)})
plt.bar(df['Ship_Mode'],df['Profit'], color='red')
# Out:
# <BarContainer object of 1917 artists>

# %%
sns.set(rc={'figure.figsize':(20,8)})
plt.bar(df['Ship_Mode'],df['Sales'], color='black')
# Out:
# <BarContainer object of 1917 artists>

# %%
data = df.groupby('Segment')[['Sales', 'Profit']].sum()
data.plot(kind='bar', rot=0)
plt.title('Total Sales and Profit by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Amount')
plt.show()

# %%
sns.regplot(x='Discount', y='Profit', data=df)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %%
sns.barplot(x="Region", y="Profit", data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Add the Cells below and Find out underlying Trends from the dataset
# - Make sure to write your hypothesis and test based on it
# - if hypothesis is not correct, explain what could be the reason
