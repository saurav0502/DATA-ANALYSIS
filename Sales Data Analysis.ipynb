# %% [markdown]
# # Importing the library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the csv file

# %%
df1 = pd.read_csv(r"C:\Users\lenovo\Downloads\train.csv")

# %%
df2 = pd.read_csv(r"C:\Users\lenovo\Downloads\test.csv")

# %% [markdown]
# # df1 is the Train Data

# %%
df1
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# # df2 is Test data

# %%
df2
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %% [markdown]
# # Question 1

# %% [markdown]
# # Now cleaning the data

# %% [markdown]
# # Train Data

# %%
df1.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df1["Product_Category_3"].value_counts()
# Out:
# 16.0    32636
# 15.0    28013
# 14.0    18428
# 17.0    16702
# 5.0     16658
# 8.0     12562
# 9.0     11579
# 12.0     9246
# 13.0     5459
# 6.0      4890
# 18.0     4629
# 4.0      1875
# 11.0     1805
# 10.0     1726
# 3.0       613
# Name: Product_Category_3, dtype: int64

# %%
df1['Product_Category_2'].fillna(df1['Product_Category_2'].mean(), inplace=True)

# %%
df1['Product_Category_3'].fillna(df1['Product_Category_3'].mean(), inplace=True)

# %%
df1.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
for i in df1.columns:
    print(df1[i].unique(),'\n')
# Out:
# [1000001 1000002 1000003 ... 1004113 1005391 1001529]
#
# ['P00069042' 'P00248942' 'P00087842' ... 'P00370293' 'P00371644'
#  'P00370853']
#
# ['F' 'M']
#
# ['0-17' '55+' '26-35' '46-50' '51-55' '36-45' '18-25']
#
# [10 16 15  7 20  9  1 12 17  0  3  4 11  8 19  2 18  5 14 13  6]
#
# ['A' 'C' 'B']
#
# ['2' '4+' '3' '1' '0']
#
# [0 1]
#
# [ 3  1 12  8  5  4  2  6 14 11 13 15  7 16 18 10 17  9 20 19]
#
# [ 9.84232925  6.         14.          2.          8.         15.
#  16.         11.          5.          3.          4.         12.
#   9.         10.         17.         13.          7.         18.        ]
#
# [12.66824321 14.         17.          5.          4.         16.
#  15.          8.          9.         13.          6.         12.
#   3.         18.         11.         10.        ]
#
# [ 8370 15200  1422 ...   135   123   613]

# %%
age_map = {'0-17': 1, '18-25': 5, '26-35': 7, '36-45': 6, '46-50': 4, '51-55': 3, '55+': 2}

# %%
df1["Age"]=df1["Age"].map(age_map)

# %%
gender_map = {"M" : 2 ,"F" : 1}

# %%
df1["Gender"]=df1["Gender"].map(gender_map)

# %%
df1
# Out:
#         User_ID Product_ID  Gender  Age  Occupation City_Category  \
# 0       1000001  P00069042       1    1          10             A
# 1       1000001  P00248942       1    1          10             A
# 2       1000001  P00087842       1    1          10             A
# 3       1000001  P00085442       1    1          10             A
# 4       1000002  P00285442       2    2          16             C
# ...         ...        ...     ...  ...         ...           ...
# 550063  1006033  P00372445       2    3          13             B
# 550064  1006035  P00375436       1    7           1             C
# 550065  1006036  P00375436       1    7          15             B
# 550066  1006038  P00375436       1    2           1             C
# 550067  1006039  P00371644       1    4           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df1["Stay_In_Current_City_Years"]=df1["Stay_In_Current_City_Years"].str.replace('+','',regex=True)

# %%
for i in df1.columns:
    print(df1[i].unique(),'\n')
# Out:
# [1000001 1000002 1000003 ... 1004113 1005391 1001529]
#
# ['P00069042' 'P00248942' 'P00087842' ... 'P00370293' 'P00371644'
#  'P00370853']
#
# [1 2]
#
# [1 2 7 4 3 6 5]
#
# [10 16 15  7 20  9  1 12 17  0  3  4 11  8 19  2 18  5 14 13  6]
#
# ['A' 'C' 'B']
#
# ['2' '4' '3' '1' '0']
#
# [0 1]
#
# [ 3  1 12  8  5  4  2  6 14 11 13 15  7 16 18 10 17  9 20 19]
#
# [ 9.84232925  6.         14.          2.          8.         15.
#  16.         11.          5.          3.          4.         12.
#   9.         10.         17.         13.          7.         18.        ]
#
# [12.66824321 14.         17.          5.          4.         16.
#  15.          8.          9.         13.          6.         12.
#   3.         18.         11.         10.        ]
#
# [ 8370 15200  1422 ...   135   123   613]

# %%
df1.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                          int64
# Age                             int64
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
df1["Stay_In_Current_City_Years"]=df1["Stay_In_Current_City_Years"].astype("int64")

# %%
df1
# Out:
#         User_ID Product_ID  Gender  Age  Occupation City_Category  \
# 0       1000001  P00069042       1    1          10             A
# 1       1000001  P00248942       1    1          10             A
# 2       1000001  P00087842       1    1          10             A
# 3       1000001  P00085442       1    1          10             A
# 4       1000002  P00285442       2    2          16             C
# ...         ...        ...     ...  ...         ...           ...
# 550063  1006033  P00372445       2    3          13             B
# 550064  1006035  P00375436       1    7           1             C
# 550065  1006036  P00375436       1    7          15             B
# 550066  1006038  P00375436       1    2           1             C
# 550067  1006039  P00371644       1    4           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                   3
# ...

# %% [markdown]
# # Test data

# %%
df2.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
df2['Product_Category_2'].fillna(df2['Product_Category_2'].mean(), inplace=True)

# %%
df2['Product_Category_3'].fillna(df2['Product_Category_3'].mean(), inplace=True)

# %%
df2.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# dtype: int64

# %%
for i in df2.columns:
    print(df2[i].unique(),'\n')
# Out:
# [1000004 1000009 1000010 ... 1001656 1005796 1001189]
#
# ['P00128942' 'P00113442' 'P00288442' ... 'P00270742' 'P00253842'
#  'P00325442']
#
# ['M' 'F']
#
# ['46-50' '26-35' '36-45' '18-25' '51-55' '55+' '0-17']
#
# [ 7 17  1 15  3  0  8 16  4 12 13 18 11  9  2 20 14 10  6 19  5]
#
# ['B' 'C' 'A']
#
# ['2' '0' '4+' '1' '3']
#
# [1 0]
#
# [ 1  3  5  4  2 10 15 18  8 13  6 11 12  7 16 14 17  9]
#
# [11.          5.         14.          9.          3.          4.
#  13.          2.          9.84958606  8.         15.         17.
#  12.         16.          6.         10.         18.          7.        ]
#
# [12.66945395 12.         15.          9.         16.         14.
#   4.          3.          5.          8.         17.         13.
#  11.         10.          6.         18.        ]

# %%
df2["Age"].value_counts()
# Out:
# 26-35    93428
# 36-45    46711
# 18-25    42293
# 46-50    19577
# 51-55    16283
# 55+       9075
# 0-17      6232
# Name: Age, dtype: int64

# %%
age_map = {'0-17': 1, '18-25': 5, '26-35': 7, '36-45': 6, '46-50': 4, '51-55': 3, '55+': 2}

# %%
df2["Age"]=df2["Age"].map(age_map)

# %%
gender_map = {"M" : 2 ,"F" : 1}

# %%
df2["Gender"]=df2["Gender"].map(gender_map)

# %%
df2["Stay_In_Current_City_Years"]=df2["Stay_In_Current_City_Years"].str.replace('+','',regex=True)

# %%
df2["Stay_In_Current_City_Years"]=df2["Stay_In_Current_City_Years"].astype("int64")

# %%
df2
# Out:
#         User_ID Product_ID  Gender  Age  Occupation City_Category  \
# 0       1000004  P00128942       2    4           7             B
# 1       1000009  P00113442       2    7          17             C
# 2       1000010  P00288442       1    6           1             B
# 3       1000010  P00145342       1    6           1             B
# 4       1000011  P00053842       1    7           1             C
# ...         ...        ...     ...  ...         ...           ...
# 233594  1006036  P00118942       1    7          15             B
# 233595  1006036  P00254642       1    7          15             B
# 233596  1006036  P00031842       1    7          15             B
# 233597  1006037  P00124742       1    4           1             C
# 233598  1006039  P00316642       1    4           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               1                   1
# ...

# %%
df2.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                          int64
# Age                             int64
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %%
df1
# Out:
#         User_ID Product_ID  Gender  Age  Occupation City_Category  \
# 0       1000001  P00069042       1    1          10             A
# 1       1000001  P00248942       1    1          10             A
# 2       1000001  P00087842       1    1          10             A
# 3       1000001  P00085442       1    1          10             A
# 4       1000002  P00285442       2    2          16             C
# ...         ...        ...     ...  ...         ...           ...
# 550063  1006033  P00372445       2    3          13             B
# 550064  1006035  P00375436       1    7           1             C
# 550065  1006036  P00375436       1    7          15             B
# 550066  1006038  P00375436       1    2           1             C
# 550067  1006039  P00371644       1    4           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                   3
# ...

# %% [markdown]
# # Perform Data processing after the data cleaning part

# %%
df1.describe()
# Out:
#             User_ID         Gender           Age     Occupation  \
# count  5.500680e+05  550068.000000  550068.00000  550068.000000
# mean   1.003029e+06       1.753105       5.54823       8.076707
# std    1.727592e+03       0.431205       1.62801       6.522660
# min    1.000001e+06       1.000000       1.00000       0.000000
# 25%    1.001516e+06       2.000000       5.00000       2.000000
# 50%    1.003077e+06       2.000000       6.00000       7.000000
# 75%    1.004478e+06       2.000000       7.00000      14.000000
# max    1.006040e+06       2.000000       7.00000      20.000000
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# count               550068.000000   550068.000000       550068.000000
# mean                     1.858418        0.409653            5.404270
# std                      1.289443        0.491770            3.936211
# min                      0.000000        0.000000            1.000000
# ...

# %%
df1.corr()
# Out:
#                              User_ID    Gender       Age  Occupation  \
# User_ID                     1.000000 -0.033474  0.037594   -0.023971
# Gender                     -0.033474  1.000000  0.037158    0.117291
# Age                         0.037594  0.037158  1.000000   -0.035127
# Occupation                 -0.023971  0.117291 -0.035127    1.000000
# Stay_In_Current_City_Years -0.030737  0.014660  0.027215    0.030005
# Marital_Status              0.020443 -0.011603 -0.082919    0.024280
# Product_Category_1          0.003825 -0.045594 -0.027491   -0.007618
# Product_Category_2          0.001267 -0.015300 -0.006840   -0.000317
# Product_Category_3          0.001888  0.014978 -0.002923    0.007265
# Purchase                    0.004716  0.060346 -0.000126    0.020833
#
#                             Stay_In_Current_City_Years  Marital_Status  \
# User_ID                                      -0.030737        0.020443
# ...

# %%
df1.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                          int64
# Age                             int64
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %% [markdown]
# # Outlier Analysis

# %%
col=['Age','Occupation','Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1','Product_Category_2']

# %%
for c in col:
  percentile25 = df1[c].quantile(0.25)
  percentile75 = df1[c].quantile(0.75)
  IQR = percentile75 - percentile25
  Upperlimit = percentile75 + 1.5*IQR
  Lowerlimit = percentile25 - 1.5*IQR
  df1= df1[df1[c]<=Upperlimit]
  df1 = df1[df1[c]>=Lowerlimit]
  plt.figure()
  sns.boxplot(y=c, data =df1)

# %%
sns.set(rc={'figure.figsize':(20,8)})
sns.heatmap(df1.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
# sns.pairplot(df1[['Age','Occupation','Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1','Product_Category_2','Product_Category_3']],hue='Age')

# %% [markdown]
# # Visualization

# %%
sns.set(rc={'figure.figsize':(20,8)})
df1['Age'].plot.hist(color="green")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.set(rc={'figure.figsize':(20,8)})
df1['Occupation'].plot.hist(color="red")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.set(rc={'figure.figsize':(20,8)})
df1['Stay_In_Current_City_Years'].plot.hist(color="black")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Age vs Purchased

# %%
sns.set(rc={'figure.figsize':(20,8)})
a=sns.lineplot(x=df1['Age'],y=df1["Purchase"],color = "red")

# %%
# Occupation vs Purchased

# %%
sns.set(rc={'figure.figsize':(20,8)})
plt.scatter(df1['Occupation'], df1['Purchase'])
plt.xlabel('Occupation')
plt.ylabel('Purchase')
plt.title('Relationship between Occupation and Purchase')
plt.show()

# %%
# Product_category_1 vs Purchased

# %%
sns.set(rc={'figure.figsize':(20,8)})
category1 = df1.groupby('Product_Category_1')['Purchase'].sum()
category1.plot(kind='bar')
plt.xlabel('Product Category 1')
plt.ylabel('Total Purchases')
plt.title('Total Purchases by Product Category')
plt.show()

# %%
# Product_category_2 vs Purchased

# %%
sns.set(rc={'figure.figsize':(20,8)})
category2 = df1.groupby('Product_Category_2')['Purchase'].sum()
category2.plot(kind='bar',color = "red")
plt.xlabel('Product Category 2')
plt.ylabel('Total Purchases')
plt.title('Total Purchases by Product Category')
plt.show()

# %%
# Product_category_3 vs Purchased

# %%
sns.set(rc={'figure.figsize':(20,8)})
category3 = df1.groupby('Product_Category_3')['Purchase'].sum()
category3.plot(kind='bar',color = "black")
plt.xlabel('Product Category 3')
plt.ylabel('Total Purchases')
plt.title('Total Purchases by Product Category')
plt.show()

# %%
# City category pie chart

# %%
sns.set(rc={'figure.figsize':(20,8)})
category_count = df1.groupby('City_Category')['City_Category'].count()
values = category_count.values.tolist()
labels = category_count.index.tolist()
colors = ['red', 'green', 'blue']
plt.pie(values, labels=labels, colors=colors,autopct='%2.2f%%')
plt.title('Distribution of City Categories')
plt.show()

# %% [markdown]
# # 2nd Question Model Creation in Machine Learning

# %%
df1
# Out:
#         User_ID Product_ID  Gender  Age  Occupation City_Category  \
# 4       1000002  P00285442       2    2          16             C
# 5       1000003  P00193542       2    7          15             A
# 6       1000004  P00184942       2    4           7             B
# 7       1000004  P00346142       2    4           7             B
# 8       1000004   P0097242       2    4           7             B
# ...         ...        ...     ...  ...         ...           ...
# 545910  1006040  P00184342       2    7           6             B
# 545911  1006040  P00193142       2    7           6             B
# 545912  1006040  P00029842       2    7           6             B
# 545913  1006040  P00106042       2    7           6             B
# 545914  1006040  P00217442       2    7           6             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                                4               0                   8
# ...

# %%
df1.drop(columns="Product_ID",inplace=True)

# %%
df2
# Out:
#         User_ID Product_ID  Gender  Age  Occupation City_Category  \
# 0       1000004  P00128942       2    4           7             B
# 1       1000009  P00113442       2    7          17             C
# 2       1000010  P00288442       1    6           1             B
# 3       1000010  P00145342       1    6           1             B
# 4       1000011  P00053842       1    7           1             C
# ...         ...        ...     ...  ...         ...           ...
# 233594  1006036  P00118942       1    7          15             B
# 233595  1006036  P00254642       1    7          15             B
# 233596  1006036  P00031842       1    7          15             B
# 233597  1006037  P00124742       1    4           1             C
# 233598  1006039  P00316642       1    4           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               1                   1
# ...

# %%
df2.drop(columns="Product_ID",inplace=True)

# %%
# Now Conact The Table

# %%
df=pd.concat([df1,df2])

# %%
df
# Out:
#         User_ID  Gender  Age  Occupation City_Category  \
# 4       1000002       2    2          16             C
# 5       1000003       2    7          15             A
# 6       1000004       2    4           7             B
# 7       1000004       2    4           7             B
# 8       1000004       2    4           7             B
# ...         ...     ...  ...         ...           ...
# 233594  1006036       1    7          15             B
# 233595  1006036       1    7          15             B
# 233596  1006036       1    7          15             B
# 233597  1006037       1    4           1             C
# 233598  1006039       1    4           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                                4               0                   8
# 5                                3               0                   1
# 6                                2               1                   1
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3                 0
# Purchase                      233599
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         User_ID  Gender  Age  Occupation City_Category  \
# 4       1000002       2    2          16             C
# 5       1000003       2    7          15             A
# 6       1000004       2    4           7             B
# 7       1000004       2    4           7             B
# 8       1000004       2    4           7             B
# ...         ...     ...  ...         ...           ...
# 545910  1006040       2    7           6             B
# 545911  1006040       2    7           6             B
# 545912  1006040       2    7           6             B
# 545913  1006040       2    7           6             B
# 545914  1006040       2    7           6             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                                4               0                   8
# 5                                3               0                   1
# 6                                2               1                   1
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %% [markdown]
# # Onehot Encoding

# %%
df= pd.get_dummies(df,columns=["City_Category"],drop_first=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Gender', 'Age', 'Occupation', 'Stay_In_Current_City_Years',
#        'Marital_Status', 'Product_Category_1', 'Product_Category_2',
#        'Product_Category_3', 'Purchase', 'City_Category_B', 'City_Category_C'],
#       dtype='object')

# %%
x=df[['User_ID', 'Gender', 'Age', 'Occupation', 'Stay_In_Current_City_Years',
       'Marital_Status', 'Product_Category_1', 'Product_Category_2',
       'Product_Category_3','City_Category_B', 'City_Category_C']].values

# %%
y=df["Purchase"].values

# %% [markdown]
# # Linear Regression

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train, y_test = train_test_split(x,y,test_size=0.2, random_state =25)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test =sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

reg.fit(x_train,y_train)

y_pred = reg.predict(x_test)

y_pred1 = reg.predict(x_train)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.1138785570002816

# %%
r2_score(y_train, y_pred1)
# Out:
# 0.11098688378817345

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_train,y_pred1)
# Out:
# 22043823.553724688

# %%
np.sqrt(mean_squared_error(y_train,y_pred1))
# Out:
# 4695.085042224974

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
dc=DecisionTreeRegressor()

# %%
dc.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dc.predict(x_test)
print("R2 Score for Testing data is",round((r2_score(y_test,y_pred)),4)*100)
# Out:
# R2 Score for Testing data is 51.0

# %%
y_pred=dc.predict(x_train)
print("R2 Score for Testing data is",round((r2_score(y_train,y_pred)),4)*100)
# Out:
# R2 Score for Testing data is 86.07000000000001
