# %% [markdown]
# ## Download the dataset from this [link](https://www.kaggle.com/datasets/kamyababedi/visceral-adipose). You can find the dataset description there itself. Read it carefully and answer the questions below
#
# **Make sure you write necessary Python code and use necessary visuals to support your answer**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\lenovo\Downloads\visceral_fat.csv")

# %%
df
# Out:
#      number  age (years)  ethnicity  diabetes mellitus  \
# 0         1           20        NaN                  0
# 1         2           28        0.0                  0
# 2         5           21        1.0                  0
# 3         9           25        0.0                  0
# 4        13           33        1.0                  0
# ..      ...          ...        ...                ...
# 128     278           21        0.0                  0
# 129     280           22        0.0                  0
# 130     283           19        1.0                  0
# 131     285           23        1.0                  0
# 132     287           36        0.0                  0
#
#      mean diastolic bp (mmhg)  mean systolic bp (mmhg)  \
# 0                        73.5                    125.0
# 1                        75.5                    112.0
# 2                        70.5                    116.0
# 3                        92.5                    167.0
# ...

# %% [markdown]
# #### Find out the dataset dimensions

# %%
df.shape
# Out:
# (133, 15)

# %% [markdown]
# #### Find out statistical summary of the Dataset

# %%
df.describe()
# Out:
#            number  age (years)   ethnicity  diabetes mellitus  \
# count  133.000000   133.000000  132.000000         133.000000
# mean   161.248120    25.804511    0.439394           0.007519
# std     82.703505     6.366887    0.498204           0.086711
# min      1.000000    15.000000    0.000000           0.000000
# 25%     78.000000    21.000000    0.000000           0.000000
# 50%    187.000000    25.000000    0.000000           0.000000
# 75%    228.000000    30.000000    1.000000           0.000000
# max    287.000000    43.000000    1.000000           1.000000
#
#        mean diastolic bp (mmhg)  mean systolic bp (mmhg)  \
# count                133.000000               133.000000
# mean                  70.593985               116.578947
# std                    8.657662                13.879602
# min                   51.500000                90.000000
# 25%                   64.500000               107.000000
# 50%                   70.000000               114.000000
# ...

# %% [markdown]
# #### Check for the null values in Dataset

# %%
df.isnull().sum()
# Out:
# number                            0
# age (years)                       0
# ethnicity                         1
# diabetes mellitus                 0
# mean diastolic bp (mmhg)          0
# mean systolic bp (mmhg)           0
# central armellini fat (mm)        0
# current gestational age           0
# pregnancies (number)              5
# first fasting glucose (mg/dl)    30
# bmi pregestational (kg/m)         1
# gestational age at birth          0
# type of delivery                  0
# child birth weight (g)            0
# gestational dm                    0
# dtype: int64

# %% [markdown]
# #### Check for the noise value of the dataset

# %%
for i in df.columns:
    print(df[i].unique(),'\n')
# Out:
# [  1   2   5   9  13  17  18  19  20  25  28  32  34  36  37  39  40  41
#   42  43  45  46  48  56  58  59  60  64  69  72  73  76  77  78  81  84
#   96 112 113 115 117 119 121 125 131 143 144 146 147 152 154 163 167 168
#  171 172 174 175 176 177 178 179 180 181 185 186 187 188 189 190 191 193
#  194 195 196 197 199 200 201 202 203 205 206 207 208 209 210 212 213 214
#  215 216 217 220 221 224 225 226 227 228 229 230 231 232 233 234 235 236
#  237 238 239 240 241 243 244 245 247 250 252 253 256 258 259 260 261 266
#  269 273 278 280 283 285 287]
#
# [20 28 21 25 33 18 17 23 27 22 40 37 32 39 29 30 38 19 15 31 26 36 34 24
#  35 16 43]
#
# [nan  0.  1.]
#
# [0 1]
#
# [ 73.5  75.5  70.5  92.5  79.   67.5  72.   74.5  59.5  90.   64.   62.
#   62.5  69.5  74.   64.5  81.   61.   82.5  70.   67.   72.5  84.   76.
#   52.5  66.   53.5  77.5  89.   65.   61.5  69.   63.   68.5  58.5  71.
#   65.5  81.5  60.   63.5  79.5  68.   55.   75.   85.   57.  100.5  73.
# ...

# %% [markdown]
# #### Handle the null values in the Dataset

# %%
df['first fasting glucose (mg/dl)'].fillna(df['first fasting glucose (mg/dl)'].median(), inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# number                           0
# age (years)                      0
# ethnicity                        0
# diabetes mellitus                0
# mean diastolic bp (mmhg)         0
# mean systolic bp (mmhg)          0
# central armellini fat (mm)       0
# current gestational age          0
# pregnancies (number)             0
# first fasting glucose (mg/dl)    0
# bmi pregestational (kg/m)        0
# gestational age at birth         0
# type of delivery                 0
# child birth weight (g)           0
# gestational dm                   0
# dtype: int64

# %% [markdown]
# #### Handle the Noise Values in Dataset

# %%
for i in df.columns:
    print(df[i].unique(),'\n')
# Out:
# [  2   5   9  13  17  18  19  20  25  28  32  34  36  37  39  40  41  42
#   43  45  46  56  58  59  60  64  69  72  73  76  77  78  81  84  96 112
#  113 115 117 119 121 125 131 143 144 146 147 152 154 163 167 168 171 172
#  174 175 176 177 178 179 180 181 185 186 187 188 189 190 191 193 194 195
#  196 197 199 200 202 203 205 206 207 208 209 210 212 213 214 215 216 221
#  224 225 226 227 228 229 230 231 232 233 234 235 236 237 238 241 243 244
#  245 247 250 252 253 256 258 259 260 261 266 269 273 278 280 283 285 287]
#
# [28 21 25 33 18 20 17 23 27 22 40 37 32 29 30 38 19 15 31 26 36 34 39 24
#  35 16 43]
#
# [0. 1.]
#
# [0 1]
#
# [ 75.5  70.5  92.5  79.   67.5  72.   74.5  59.5  90.   64.   62.   62.5
#   69.5  74.   64.5  81.   61.   82.5  67.   72.5  84.   76.   52.5  70.
#   66.   53.5  77.5  89.   65.   61.5  69.   63.   68.5  58.5  71.   65.5
#   81.5  60.   63.5  79.5  68.   55.   75.   85.   73.5 100.5  73.   56.5
#   78.   77.   56.   92.   76.5  83.5]
#
# ...

# %%
df.dtypes
# Out:
# number                             int64
# age (years)                        int64
# ethnicity                        float64
# diabetes mellitus                  int64
# mean diastolic bp (mmhg)         float64
# mean systolic bp (mmhg)          float64
# central armellini fat (mm)       float64
# current gestational age           object
# pregnancies (number)             float64
# first fasting glucose (mg/dl)    float64
# bmi pregestational (kg/m)        float64
# gestational age at birth          object
# type of delivery                   int64
# child birth weight (g)             int64
# gestational dm                     int64
# dtype: object

# %% [markdown]
# #### Check the outliers for various Thresholds (1.5 x IQR , 2 X IQR and so on) for Numeric Columns

# %%
df.columns
# Out:
# Index(['number', 'age (years)', 'ethnicity', 'diabetes mellitus',
#        'mean diastolic bp (mmhg)', 'mean systolic bp (mmhg)',
#        'central armellini fat (mm)', 'current gestational age',
#        'pregnancies (number)', 'first fasting glucose (mg/dl)',
#        'bmi pregestational (kg/m)', 'gestational age at birth',
#        'type of delivery', 'child birth weight (g)', 'gestational dm'],
#       dtype='object')

# %%
col = ['number', 'age (years)', 'ethnicity',
       'mean diastolic bp (mmhg)', 'mean systolic bp (mmhg)',
       'central armellini fat (mm)','pregnancies (number)', 'first fasting glucose (mg/dl)',
       'bmi pregestational (kg/m)', 'child birth weight (g)']

# %%
for c in col:
  percentile25 = df[c].quantile(0.25)
  percentile75 = df[c].quantile(0.75)
  IQR = percentile75 - percentile25
  Upperlimit = percentile75 + 1.5*IQR
  Lowerlimit = percentile25 - 1.5*IQR
  df= df[df[c]<=Upperlimit]
  df = df[df[c]>=Lowerlimit]
  plt.figure()
  sns.boxplot(y=c, data =df)

# %%
for c in col:
  percentile25 = df[c].quantile(0.25)
  percentile75 = df[c].quantile(0.75)
  IQR = percentile75 - percentile25
  Upperlimit = percentile75 + 2*IQR
  Lowerlimit = percentile25 - 2*IQR
  df= df[df[c]<=Upperlimit]
  df = df[df[c]>=Lowerlimit]
  plt.figure()
  sns.boxplot(y=c, data =df)

# %% [markdown]
# #### Find out trelation between ethnecity and current gestational diabetes. Explain your hypothesis and analysis

# %%
df.head(1)
# Out:
#    number  age (years)  ethnicity  diabetes mellitus  \
# 1       2           28        0.0                  0
#
#    mean diastolic bp (mmhg)  mean systolic bp (mmhg)  \
# 1                      75.5                    112.0
#
#    central armellini fat (mm) current gestational age  pregnancies (number)  \
# 1                        43.1                    11,5                   1.0
#
#    first fasting glucose (mg/dl)  bmi pregestational (kg/m)  \
# 1                           76.0                       21.5
#
#   gestational age at birth  type of delivery  child birth weight (g)  \
# 1                     39,1                 0                    2810
#
#    gestational dm
# 1               0

# %%
df[["ethnicity","first fasting glucose (mg/dl)"]].corr()
# Out:
#                                ethnicity  first fasting glucose (mg/dl)
# ethnicity                       1.000000                      -0.073587
# first fasting glucose (mg/dl)  -0.073587                       1.000000

# %%
df.groupby('ethnicity')['first fasting glucose (mg/dl)'].value_counts(normalize=True).unstack().plot(kind='bar', stacked=True)
plt.show()

# %% [markdown]
# #### What is the relation between Previous Diabetes Mellitus and Type of Delivery

# %%
df[['diabetes mellitus','type of delivery']].corr()
# Out:
#                    diabetes mellitus  type of delivery
# diabetes mellitus           1.000000         -0.051933
# type of delivery           -0.051933          1.000000

# %%
df.groupby('diabetes mellitus')['type of delivery'].value_counts(normalize=True).unstack().plot(kind='bar', stacked=True)
plt.show()

# %% [markdown]
# #### Find out the relation between Age and Gestational age of birth. Explain the outcome

# %%
l = []
for i in df['current gestational age'].str.split(','):
    l.append((int(i[0])*7)+int(i[1]))
df['current gestational age'] = l

# %%
df['current gestational age']
# Out:
# 1       82
# 2       90
# 4       79
# 5       89
# 6       92
#       ...
# 126    105
# 127    140
# 128     74
# 130    140
# 131     75
# Name: current gestational age, Length: 105, dtype: int64

# %%
l = []
for i in df['gestational age at birth'].str.split(','):
    l.append((int(i[0])*7)+int(i[1]))
df['gestational age at birth'] = l

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 1 to 131
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   number                         105 non-null    int64
#  1   age (years)                    105 non-null    int64
#  2   ethnicity                      105 non-null    float64
#  3   diabetes mellitus              105 non-null    int64
#  4   mean diastolic bp (mmhg)       105 non-null    float64
#  5   mean systolic bp (mmhg)        105 non-null    float64
#  6   central armellini fat (mm)     105 non-null    float64
#  7   current gestational age        105 non-null    int64
#  8   pregnancies (number)           105 non-null    float64
#  9   first fasting glucose (mg/dl)  105 non-null    float64
#  10  bmi pregestational (kg/m)      105 non-null    float64
#  11  gestational age at birth       105 non-null    int64
# ...

# %%
df[['gestational age at birth','current gestational age']].corr()
# Out:
#                           gestational age at birth  current gestational age
# gestational age at birth                  1.000000                 0.023981
# current gestational age                   0.023981                 1.000000

# %% [markdown]
# #### Find the relation of BMI pregestational, First fasting glucose with Gestational DM

# %%
df[['bmi pregestational (kg/m)','first fasting glucose (mg/dl)','gestational dm']].corr().iloc[:,-1]
# Out:
# bmi pregestational (kg/m)        0.268579
# first fasting glucose (mg/dl)    0.258554
# gestational dm                   1.000000
# Name: gestational dm, dtype: float64

# %% [markdown]
# #### Classify the dataset in the various reasonable clusters (Use K-Means), and explain the feature selection for clusters

# %%
from sklearn.cluster import KMeans

# %%
inertia=[]
for i in range(1,15):
    kmeans=KMeans(i)
    kmeans.fit(df)
    inertia.append(kmeans.inertia_)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
sns.lineplot(x=range(1,15),y=inertia,marker="o")
# Out:
# <AxesSubplot:>

# %%
kmeans=KMeans(6)

# %%
kmeans.fit(df)
# Out:
# KMeans(n_clusters=6)

# %%
kmeans.predict(df)
# Out:
# array([0, 3, 1, 0, 4, 4, 4, 1, 0, 2, 2, 4, 2, 4, 4, 1, 2, 4, 1, 1, 2, 1,
#        2, 2, 0, 0, 2, 0, 0, 0, 2, 0, 4, 2, 1, 4, 0, 0, 2, 0, 4, 0, 2, 2,
#        5, 1, 2, 5, 0, 4, 4, 2, 0, 2, 1, 2, 4, 2, 1, 0, 3, 4, 5, 2, 4, 1,
#        2, 1, 2, 0, 1, 2, 1, 2, 2, 3, 0, 4, 2, 4, 2, 0, 2, 4, 1, 0, 2, 2,
#        2, 0, 2, 0, 5, 0, 3, 4, 4, 0, 2, 1, 4, 2, 1, 2, 2])

# %%
df["clusters"]=kmeans.predict(df)

# %%
df
# Out:
#      number  age (years)  ethnicity  diabetes mellitus  \
# 1         2           28        0.0                  0
# 2         5           21        1.0                  0
# 4        13           33        1.0                  0
# 5        17           18        0.0                  0
# 6        18           18        0.0                  0
# ..      ...          ...        ...                ...
# 126     269           19        0.0                  0
# 127     273           21        0.0                  0
# 128     278           21        0.0                  0
# 130     283           19        1.0                  0
# 131     285           23        1.0                  0
#
#      mean diastolic bp (mmhg)  mean systolic bp (mmhg)  \
# 1                        75.5                    112.0
# 2                        70.5                    116.0
# 4                        79.0                    137.0
# 5                        67.5                    111.5
# ...

# %% [markdown]
# ## Add the Cells below and Find out more underlying Trends from the dataset (***Bonus Points***)
# - Make sure to write your hypothesis and test based on it
# - if hypothesis is not correct, explain what could be the reason
